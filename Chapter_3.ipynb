# %%
# 以下のライブラリを使うので、あらかじめ読み込んでおいてください
import numpy as np
import numpy.random as random
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame
from sklearn import linear_model

# 可視化ライブラリ
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
sns.set()
# %matplotlib inline

# 小数第３位まで表示
# %precision 3
# Out:
# '%.3f'

# %%
import requests, zipfile
import io
from io import StringIO

# %%
data_math = pd.read_csv("./chap3/student-mat.csv", sep=";")
data_math.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
data_math.groupby("sex")["age"].mean()
data_math.absences
# Out:
# 0       6
# 1       4
# 2      10
# 3       2
# 4       4
#        ..
# 390    11
# 391     3
# 392     3
# 393     0
# 394     5
# Name: absences, Length: 395, dtype: int64

# %%
plt.hist(data_math["absences"])
plt.xlabel("absences")
plt.ylabel("count")

plt.grid(True)

# %%
print(data_math.absences.mean())
print(data_math.absences.median())
print(data_math.absences.mode())
# Out:
# 5.708860759493671
# 4.0
# 0    0
# Name: absences, dtype: int64

# %%
data_math.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
plt.boxplot(data_math.G1)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ff438ac8a90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ff438a50130>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ff438ac8760>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ff438a50850>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ff438a50be0>],
#  'means': []}

# %%
data_math.std(ddof=0) / data_math.mean()
# Out:
# /tmp/ipykernel_89696/2899881521.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data_math.std(ddof=0) / data_math.mean()
# age           0.076330
# Medu          0.397673
# Fedu          0.431019
# traveltime    0.481058
# studytime     0.411791
# failures      2.222501
# famrel        0.227042
# freetime      0.308334
# goout         0.357645
# Dalc          0.600679
# Walc          0.561409
# health        0.390651
# absences      1.400097
# G1            0.303881
# G2            0.350641
# G3            0.439324
# dtype: float64

# %%
plt.plot(data_math["G1"], data_math["G3"], "o")
plt.xlabel("G3")
plt.ylabel("G1")
plt.grid(True)

# %%
np.cov(data_math["G1"], data_math["G3"], ddof=0)
# Out:
# array([[10.989, 12.157],
#        [12.157, 20.936]])

# %%
sns.pairplot(data_math[["Dalc", "Walc", "G1", "G2"]])

# %%
data_por = pd.read_csv("./chap3/student-por.csv", sep=";")
data_math = pd.read_csv("./chap3/student-mat.csv", sep=";")

# %%
merged = pd.merge(data_por, data_math, on=['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason', 'nursery', 'internet'], suffixes=("_math", "_por"))
merged
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 377     MS   F   18       R     GT3       T     4     4   teacher   at_home
# 378     MS   F   19       R     GT3       T     2     3  services     other
# 379     MS   F   18       U     LE3       T     3     1   teacher  services
# 380     MS   M   17       U     LE3       T     3     1  services  services
# 381     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
merged.describe()
# Out:
#               age        Medu        Fedu  traveltime_math  studytime_math  \
# count  382.000000  382.000000  382.000000       382.000000      382.000000
# mean    16.586387    2.806283    2.565445         1.445026        2.039267
# std      1.173470    1.086381    1.096240         0.699354        0.845571
# min     15.000000    0.000000    0.000000         1.000000        1.000000
# 25%     16.000000    2.000000    2.000000         1.000000        1.000000
# 50%     17.000000    3.000000    3.000000         1.000000        2.000000
# 75%     17.000000    4.000000    4.000000         2.000000        2.000000
# max     22.000000    4.000000    4.000000         4.000000        4.000000
#
#        failures_math  famrel_math  freetime_math  goout_math   Dalc_math  ...  \
# count     382.000000   382.000000     382.000000  382.000000  382.000000  ...
# mean        0.141361     3.942408       3.230366    3.117801    1.476440  ...
# ...

# %%
sns.pairplot(merged[["Medu", "Fedu", "G3_math"]])

# %%
from sklearn import linear_model
reg = linear_model.LinearRegression()

# %%
x = data_math.loc[:, ["G1"]].values
y = data_math.loc[:, ["G3"]].values

# %%
reg.fit(x, y)
print(reg.coef_, reg.intercept_)
# Out:
# [[1.106]] [-1.653]

# %%
plt.scatter(x, y)
plt.xlabel("G1")
plt.ylabel("G3")

plt.plot(x, reg.predict(x))
plt.grid(True)

# %%
x = data_por.loc[:, ["G1"]].values
y = data_por.loc[:, ["G3"]].values
reg.fit(x, y)
print(reg.coef_, reg.intercept_)
plt.scatter(x, y)
plt.xlabel("G1")
plt.xlabel("G3")
plt.grid(True)
plt.plot(x, reg.predict(x))
# Out:
# [[0.973]] [0.82]

# %%
x = data_por.loc[:, ["absences"]].values
y = data_por.loc[:, ["G3"]].values
reg.fit(x, y)
print(reg.coef_, reg.intercept_)
plt.scatter(x, y)
plt.xlabel("G1")
plt.xlabel("G3")
plt.grid(True)
plt.plot(x, reg.predict(x))
print('決定係数:', reg.score(x, y))
# Out:
# [[-0.064]] [12.139]
# 決定係数: 0.008350131955637385

# %%
wine = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv', sep=';')
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
wine.describe().to_csv("test.csv")

# %%
plt.scatter(wine["fixed acidity"], wine["volatile acidity"])

# %%
data_math.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
data_math_female = data_math[data_math.sex == "F"]
data_math_male = data_math[data_math.sex == "M"]

# %%
data_math_female
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 385     MS   F   18       R     GT3       T     2     2   at_home     other
# 386     MS   F   18       R     GT3       T     4     4   teacher   at_home
# 387     MS   F   19       R     GT3       T     2     3  services     other
# 388     MS   F   18       U     LE3       T     3     1   teacher  services
# 389     MS   F   18       U     GT3       T     1     1     other     other
#
# ...

# %%
female_g1 = data_math_female.G1.sort_values()
male_g1 = data_math_male.G1.sort_values()

# %%
len_f = np.arange(len(female_g1))
len_m = np.arange(len(male_g1))
